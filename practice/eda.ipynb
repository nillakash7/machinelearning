# %% [markdown]
# ### Plotting for Exploratory data analysis (EDA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Load the dataset
pd.options.display.max_columns = None
# To make this notebook's output identical for every run
np.random.seed(0)
data = pd.read_csv('../data/practice/iris.csv')
# Display data randomly
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ### Dimension of the data

# %%
# Display the number of rows and columns in the dataset
print(data.shape)
# Out:
# (150, 5)

# %% [markdown]
# ### List of columns

# %%
print(data.columns)
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='str')

# %% [markdown]
# ### How many records for each category/dependent variable are present

# %%
data["variety"].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### 2-D scatter plot

# %%
data.plot(kind='scatter', x='sepal.length', y='sepal.width')
plt.title('Sepal Length vs Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length vs Sepal Width')

# %%
data.plot(kind='scatter', x='petal.length', y='petal.width')
plt.title('Petal Length vs Petal Width')
# Out:
# Text(0.5, 1.0, 'Petal Length vs Petal Width')

# %% [markdown]
# ### 2-D scatter plot with colored data points

# %%
sns.set_style("whitegrid")
sns.FacetGrid(data, hue="variety", height=5).map(plt.scatter, "sepal.length", "sepal.width").add_legend()
sns.FacetGrid(data, hue="variety", height=5).map(plt.scatter, "petal.length", "petal.width").add_legend()
plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# Setosa can be linearly separable from Versicolor and Virginica in terms of sepal length & width and petal length & width<br>
# If a new data point falls in the range sepal.length (4.5 to 6.5) & sepal.width (2.8 to 4.5) as well as petal.length (0-3) & petal.width (0-1), it can be categorized as Setosa<br>
# Separating Versicolor from Virginica is challenging using sepal.length & sepal.width but can be linearly separable using petal.length (3-5) & petal.width (1 - 1.75)

# %% [markdown]
# ### Pair plot

# %%
sns.set_style("whitegrid")
sns.pairplot(data, hue="variety")
plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# petal_length and petal_width are very important features to separate the flowers <br>
# They can be separated by using simple if-else condition

# %% [markdown]
# ### Use Histogram

# %%
sns.FacetGrid(data, hue="variety", height=5).map(sns.histplot, "sepal.length").add_legend()
plt.title('Distribution of Sepal Length by Variety')
plt.show()

# %%
sns.FacetGrid(data, hue="variety", height=5).map(sns.kdeplot, "sepal.width").add_legend()
plt.title('Distribution of Sepal Width by Variety')
plt.show()

# %%
sns.FacetGrid(data, hue="variety", height=5).map(sns.kdeplot, "petal.length").add_legend()
plt.title('Distribution of Petal Length by Variety')
plt.show()

# %%
sns.FacetGrid(data, hue="variety", height=5).map(sns.kdeplot, "petal.width").add_legend()
plt.title('Distribution of Petal Width by Variety')
plt.show()

# %% [markdown]
# ### Objective: Classify a new flower in 3 of the categories (Supervised - Classification)

# %% [markdown]
# ### Feature/Indepdent Variables
